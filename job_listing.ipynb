# %%
# %load_ext autoreload
# %autoreload 2

# %%
from backend.extractor.utils import prepare_html, parse_html
from backend.fetcher.fetcher import fetch_page
from backend.extractor.extractor import find_path, find_string_tag
from backend.extractor.task.single_path_extractor import SinglePathElementExtractor
from backend.fetcher.fetcher import fetch_multiple_pages

# %%
urls = [
    # "https://www.topcv.vn/viec-lam-it",
    "https://www.topcv.vn/viec-lam-it?sort=high_salary&skill_id=&skill_id_other=&keyword=&company_field=&position=50&salary=&page=2",
    # "https://www.topcv.vn/viec-lam-it?sort=high_salary&skill_id=&skill_id_other=&keyword=&company_field=&position=50&salary=&page=3",
    # "https://www.topcv.vn/viec-lam-it?sort=high_salary&skill_id=&skill_id_other=&keyword=&company_field=&position=50&salary=&page=4",
    # "https://www.topcv.vn/viec-lam-it?sort=high_salary&skill_id=&skill_id_other=&keyword=&company_field=&position=50&salary=&page=5",
]
url = "https://www.topcv.vn/viec-lam-it?sort=high_salary&skill_id=&skill_id_other=&keyword=&company_field=&position=50&salary=&page=4"
job_page = await fetch_page(url, static_fetch=False, scroll=False, expand=False)
# Out:
# Timeout occurred after 30 seconds. Capturing the available content.

# %%
from backend.extractor.task.container_extractor import ContainerExtractor


example_input = {
    "role": [
        (
            "Thực Tập Sinh Uiux Designer",
            "",
        ),
    ],
    "company": [
        (
            "CÔNG TY CỔ PHẦN CÔNG NGHỆ & DỊCH VỤ Y TẾ SỐ MED-ON",
            "by_class",
        )
    ],
    "skills": [("Designer", "by_class")],
    "salary": [("Thoả thuận", "by_class")],
}
extractor = ContainerExtractor(
    example_input=example_input, html=job_page
)
# Out:
# 2024-06-29 14:19:01,698 - utils.py: parse_html(): 83:	Parsing HTML string to BeautifulSoup object
# --------
# 2024-06-29 14:19:01,854 - utils.py: clean_html(): 20:	Cleaning HTML, removing all path that does not contains navigable string
# --------
# <!DOCTYPE html>
# <html lang="vi"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="https://static.topcv.vn/v4/image/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="1478418029113221" property="fb:app_id"/>
# <meta content="HapqoIekfYnEAn7EwjPsejUX8Sv3w9mDS62WIUVk" name="csrf-token"/>
# <meta content="okX9WYRRKSr_EuYuN-C58UPMnAAusti-V-UFcpJEVZg" name="google-site-verification"/>
# <meta content="UTd2SHpqb1hYdC9mUnV4YUFDN3U0QT090" name="dmca-site-verification"/>
# <link href="https://www.googletagmanager.com" rel="preconnect"/>
# <link href="https://analytics.tiktok.com" rel="preconnect"/>
# ...

# %%
example_content = await extractor.container_extract_run_task()
# Out:
# 2024-06-29 14:19:04,127 - container_extractor.py: container_extract_run_task(): 91:	STEP 1: SAVING SEARCH STRINGS TO EXTRACT ITEM DICTIONARIES
# --------
# 2024-06-29 14:19:04,127 - container_extractor.py: prepare_extract_item(): 49:	1a. Getting the tag for content Thá»±c Táº­p Sinh Uiux Designer
# --------
# 2024-06-29 14:19:04,129 - extractor.py: find_string_tag(): 16:	Found string in soup at: <span data-container="body" data-original-title="Thá»±c Táº­p Sinh Uiux Designer" data-placement="top" data-toggle="tooltip" title="">Thá»±c Táº­p Sinh Uiux Designer</span>
# --------
# 2024-06-29 14:19:04,131 - container_extractor.py: prepare_extract_item(): 49:	1a. Getting the tag for content CÃNG TY Cá» PHáº¦N CÃNG NGHá» & Dá»CH Vá»¤ Y Táº¾ Sá» MED-ON
# --------
# ...

# %%
example_content
# Out:
# [{'role': 'Thực Tập Sinh Uiux Designer. Playable Ads Intern - Không Yêu Cầu Kinh Nghiệm. . Thực Tập Sinh AI Engineer. . AI Engineer (NLP Engineer). . Thực Tập Sinh Reactjs. Fresher Front End Developer. Intern Dự Án Phần Mềm. Thực Tập Sinh Lập Trình Viên PHP. Thực Tập Sinh Sales IT. Thực Tập Sinh Khối Công Nghệ Thông Tin - IT Intern. Game Designer Intern - Không Yêu Cầu Kinh Nghiệm. . Business Development Intern. . Intern Developer Reactjs. Intern Developer Flutter. Intern Java Developer. Software Engineer Intern. . Legal Intern. . Thực Tập Sinh Pentest. . Thực Tập Sinh Kỹ Sư Dữ Liệu. Software Engineer Intern. Intern Developer PHP Laravel. Intern Tester. Intern Python Developer. Thực Tập Sinh Python/Odoo Developer. Thực Tập Sinh Business Analysis (ERP). Database Administrator Intern. Thực Tập Sinh Nhân Sự. Intern Tester (Có Tiếng Nhật). . Business Analyst Fresher. . Thực Tập Trợ Lý Dự Án (Fulltime). Thực Tập Sinh UX/UI. . SAP ABAP Fresher. Thực Tập Sinh IOS. Thực Tập Sinh Kỹ Thuật FPT
# ...

# %%
from backend.extractor.utils import save_crawled_data_to_csv


save_crawled_data_to_csv(example_content, "results/csv/topcv_c-2fa.csv")
